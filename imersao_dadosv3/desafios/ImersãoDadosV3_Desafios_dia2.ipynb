# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasHenrique-dev/estudos_alura/blob/main/Imers%C3%A3oDadosV3_Desafios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Dia 1

# %% [markdown]
# ## Coletando a de base dados

# %%
import pandas as pd

url_dados = "https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true"

dados = pd.read_csv(url_dados, compression="zip")

dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %% [markdown]
# ##Desafio 01: Investigar por que há tanta discrepância entre tratamentos com droga e controlados
# ---

# %% [markdown]
# Isso se deve ao fato de que um tratamento dito controlado tem como objetivo isolar o objeto de pesquisa dos mais diversos fatores que possam interferir no desenvolvimento da doença estudada ou componente específico, ou seja, ele serve para analisar a relação que o objeto pesquisado normalmente teria com a doença ou componente.
#
# Já o tratamento com drogas visa testar determinados fármacos e analisar as reações obtidas pelo objeto de pesquisa.
#
# Dessa forma a discrepância se dá pelo fato de que há muitos tipos diferentes de drogas a serem testadas em várias amostras e o tratamento controlado ser único, justamente por não ter comprometimento com a quantidade ou tipo de fármaco a ser testado, servindo, assim, como parâmetro da eficácia.

# %% [markdown]
# ##Desafio 02: Plotar as 5 últimas linhas do Dataframe

# %%
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# ##Desafio 03: Mostrar as proporções das classes tratamento
# ---

# %%
dados["tratamento"].value_counts().plot.bar()
porcentagem = dados["tratamento"].value_counts(normalize= True)
proporcao = (porcentagem[0]/porcentagem[1]).round(2)
print(f"""Nos dados obtidos a proporção dos tratamentos controlados com o com uso de drogas foi aproximadamente de:
\nCom droga: {(porcentagem[0]*100).round(2)}%\nControlado: {(porcentagem[1]*100).round(2)}%\n
Em outras palavras, houve aproximadamente 1 tratamento controlado para cada {proporcao} tratamentos com drogas\n""")
# Out:
# Nos dados obtidos a proporção dos tratamentos controlados com o com uso de drogas foi aproximadamente de:
#
# Com droga: 92.16%
# Controlado: 7.84%
#
# Em outras palavras, houve aproximadamente 1 tratamento controlado para cada 11.76 tratamentos com drogas

# %% [markdown]
# ##Desafio 04: Quantos tipos de drogas foram investigadas
# ---

# %%
len(dados['droga']) #Total
# Out:
# 23814

# %%
dados['droga'].nunique() #Mostra a quantidade de valores únicos da série "droga"
# Out:
# 3289

# %%
cinco_drogas = dados['droga'].value_counts().head()
cinco_drogas #As 5 drogas mais utilizadas
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
# Name: droga, dtype: int64

# %%
cinco_drogas.plot.bar()

# %% [markdown]
# ##Desafio 05: Procurar na documentação o método query (pandas)
# ---

# %%
dados.query('tempo > 24') #APENAS OS TEMPOS MAIORES QUE 24
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23806  id_fff790a17     com_droga     48   D2  ...  1.2630  0.7823 -0.6947  0.7277
# 23807  id_fff7e6992     com_droga     48   D1  ...  0.3738  0.8636  0.4494  0.1218
# 23808  id_fff8c2444     com_droga     72   D1  ... -0.7415  0.8413 -0.4259  0.2434
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
doses_D1 = dados.query('dose == "D1"')
print(f"Total da tratamentos que usaram a dose D1: {len(doses_D1)}\n")
doses_D1.head()
# Out:
# Total da tratamentos que usaram a dose D1: 12147
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 5  id_001762a82  com_droga     24   D1  ...  1.2120  0.3765  0.7848  1.3990
#
# [5 rows x 877 columns]

# %%
pesquisa_especifica = doses_D1.query("tratamento == 'com_controle' and tempo >= 48")
print(f"Total da tratamentos que usaram a dose D1, são controlados e o tempo foi maior que 24: {len(pesquisa_especifica)}\n")
pesquisa_especifica.head()
# Out:
# Total da tratamentos que usaram a dose D1, são controlados e o tempo foi maior que 24: 650
#                id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 25   id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 81   id_00d575cfb  com_controle     72   D1  ...  0.6034  0.8906  1.0350  0.5739
# 148  id_01b05de6c  com_controle     48   D1  ...  0.2406  0.5057  0.8017  1.0280
# 175  id_01f1c58a2  com_controle     72   D1  ...  0.2932  0.7680 -0.1686  0.1007
# 186  id_020ba48d9  com_controle     48   D1  ... -0.6929 -0.3258  0.3602 -0.0595
#
# [5 rows x 877 columns]

# %% [markdown]
# ##Desafio 06: Renomear o nome das colunas, tirando o hífen "-"
# ---

# %%
dados.columns = dados.columns.str.replace("-", "")
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# ##Desafio 07: Deixar os gráficos bonitões, colocar títulos, labels.. (Matplotlib.pyplot)
# ---

# %%
import matplotlib.pyplot as plt

tipos_de_tratamentos = dados['tratamento'].value_counts()
labels = ['Droga', 'Controle']
explode = [0, 0.2]

plt.title('Tipos de Tratamentos')
plt.pie(tipos_de_tratamentos, labels=labels, shadow=True, explode=explode, autopct="%1.1f%%")
plt.show()

# %% [markdown]
# ##Desafio 08: Resumo do que foi aprendido com os dados
# ---

# %% [markdown]
# Aprendi a diferença entre tratamentos com controle e com drogas e que é normal eles distoarem muito, assim como a importantância do controle e que as expressões gênicas podem variar bastante devido a um estímulo específico. Estou animado com o assunto que vem pela frente, tanto no que diz respeito à aprendizagem de conteúdo de Data Science como o específico de tratamentos com fármacos.

# %% [markdown]
# #Dia 2

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
columns = {'droga': 'composto'}
dados.rename(columns=columns, inplace=True)
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# ##Desafio 01: Deixar o gráfico countplot ordenado

# %% [markdown]
# ###Decrescente

# %%
import seaborn as sns
import matplotlib.pyplot as plt

cod_compostos = dados['composto'].value_counts().head().index

plt.figure(figsize=(10, 8))

data = dados.query('composto in @cod_compostos')

sns.set()
ax = sns.countplot(x='composto', data=data, order=cod_compostos)
ax.set_title('Top 5 compostos')

plt.show()

# %% [markdown]
# ###Crescente

# %%
cod_compostos_invertido = cod_compostos[::-1]

plt.figure(figsize=(10, 8))

ax_crescente = sns.countplot(x='composto', data=data, order=cod_compostos_invertido)
ax_crescente.set_title("Top 5 compostos")

plt.show()

# %% [markdown]
# ##Desafio 02: Melhorar a visualização do gráfico alterando o tamanho da fonte...

# %%
plt.figure(figsize=(10, 8))

ax_estilizado = sns.countplot(x='composto', data=data, order=cod_compostos)
ax_estilizado.set_title('Top 5 compostos', fontsize=20, color="#5975A4")
ax_estilizado.set_xlabel('Composto', fontsize=20, color="#5975A4")
ax_estilizado.set_ylabel('Ocorrências', fontsize=20, color="#5975A4")

plt.show()

# %% [markdown]
# ##Desafio 03: Plotar os histogramas com seaborn

# %%
media_c = dados.loc[:, 'c0':'c99'].describe().T['mean']
media_c.head()
# Out:
# c0   -0.355156
# c1   -0.455359
# c2   -0.480542
# c3   -0.377666
# c4   -0.493552
# Name: mean, dtype: float64

# %%
plt.figure(figsize=(10, 8))

hist_c = sns.histplot(data=media_c, bins=50)
hist_c.set_title("Compostos C", fontsize=20, color='#5975A4')
hist_c.set_xlabel('Média', fontsize=20, color='#5975A4')
hist_c.set_ylabel('Ocorrências', fontsize=20, color='#5975A4')

plt.show()

# %%
columns = dados.columns
columns
# Out:
# Index(['id', 'tratamento', 'tempo', 'dose', 'composto', 'g0', 'g1', 'g2', 'g3',
#        'g4',
#        ...
#        'c90', 'c91', 'c92', 'c93', 'c94', 'c95', 'c96', 'c97', 'c98', 'c99'],
#       dtype='object', length=877)

# %%
def numero_colunas_g():
  cont = 0
  for i in range(len(columns)):
    if ('g' in columns[i]):
      cont += 1
  return cont

# %%
print(numero_colunas_g())
# Out:
# 772

# %%
media_g = dados.loc[:, 'g0':'g771'].describe().T['mean']
media_g.head()
# Out:
# g0    0.248366
# g1   -0.095684
# g2    0.152253
# g3    0.081971
# g4    0.057347
# Name: mean, dtype: float64

# %%
plt.figure(figsize=(10, 8))

hist_g = sns.histplot(data=media_g, bins=100)
hist_g.set_title("Compostos G", fontsize=20, color="#5975A4")
hist_g.set_xlabel("Média", fontsize= 20, color="#5975A4")
hist_g.set_ylabel("Ocorrências", fontsize= 20, color="#5975A4")

plt.show()

# %% [markdown]
# ##Desafio 04: Estudar sobre as estatísticas retornadas no .describe()
#
# Apesar dos valores até 75% serem próximos, a média de g é maior que a de c por ter os valores mais altos mais expressivos.

# %%
descricao_c = dados.loc[:, 'c0':'c99'].describe().T
descricao_c
# Out:
#        count      mean       std   min       25%      50%       75%    max
# c0   23814.0 -0.355156  1.752565 -10.0 -0.549300 -0.00900  0.448975  3.365
# c1   23814.0 -0.455359  2.004962 -10.0 -0.538425  0.00980  0.476875  3.915
# c2   23814.0 -0.480542  2.039346 -10.0 -0.550375 -0.00400  0.460575  2.970
# c3   23814.0 -0.377666  1.554583 -10.0 -0.601975 -0.03905  0.413100  2.408
# c4   23814.0 -0.493552  2.091888 -10.0 -0.559975  0.01140  0.470300  4.555
# ..       ...       ...       ...   ...       ...      ...       ...    ...
# c95  23814.0 -0.353726  1.629291 -10.0 -0.567975 -0.01025  0.444750  2.814
# c96  23814.0 -0.463485  2.059725 -10.0 -0.552575 -0.00125  0.465225  3.505
# c97  23814.0 -0.378241  1.703615 -10.0 -0.561000 -0.00680  0.446400  2.924
# c98  23814.0 -0.470252  1.834828 -10.0 -0.592600  0.01400  0.461275  3.111
# c99  23814.0 -0.301505  1.407918 -10.0 -0.562900 -0.01950  0.438650  3.805
#
# [100 rows x 8 columns]

# %%
descricao_g = dados.loc[:, 'g0':'g771'].describe().T
descricao_g
# Out:
#         count      mean       std     min       25%      50%       75%     max
# g0    23814.0  0.248366  1.393399  -5.513 -0.473075 -0.00885  0.525700  10.000
# g1    23814.0 -0.095684  0.812363  -5.737 -0.562200 -0.04660  0.403075   5.039
# g2    23814.0  0.152253  1.035731  -9.104 -0.437750  0.07520  0.663925   8.257
# g3    23814.0  0.081971  0.950012  -5.998 -0.429575  0.00805  0.463400  10.000
# g4    23814.0  0.057347  1.032091  -6.369 -0.470925 -0.02690  0.465375  10.000
# ...       ...       ...       ...     ...       ...      ...       ...     ...
# g767  23814.0 -0.076251  1.115477 -10.000 -0.506200  0.00990  0.511175   6.317
# g768  23814.0  0.134162  0.951264  -4.269 -0.353100  0.00540  0.409075  10.000
# g769  23814.0 -0.128018  1.230636 -10.000 -0.544600  0.00060  0.498500   5.911
# g770  23814.0 -0.219210  1.326193 -10.000 -0.554400  0.02870  0.496400  10.000
# g771  23814.0  0.101524  1.417674 -10.000 -0.523800 -0.00650  0.536950  10.000
#
# [772 rows x 8 columns]
